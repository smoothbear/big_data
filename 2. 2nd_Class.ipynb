# %% [markdown]
# <a href="https://colab.research.google.com/github/smoothbear/big_data/blob/main/2.%202nd_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
plt.plot([1, 2, 3, 4])
plt.title('EASY')
plt.xlabel('x axis label')
plt.xlabel('x axis label')
plt.show()

# %%
plt.plot([1,2,3,4], [1,8,27,64])
plt.axis([0, 10, 0, 100])
plt.grid()
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,25], '^k')
plt.axis([0,5,0,30])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 2, 3, 4], '+r')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'xg')
plt.plot([1, 2, 3, 4], [1, 8, 27, 30], 'b')
plt.grid(True, axis='x', color='pink', alpha=10, linestyle='--')

# %%
import numpy as np

t = np.arange(0, 5, 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

# %%
plt.title("Sample graph", loc='left', pad=10)
plt.plot("x")
# Out:
# Text(0.0, 1.0, 'Sample graph')
